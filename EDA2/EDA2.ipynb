# %% [markdown]
# EDA2

# %%
#importing required library
import pandas as pd 
headers=pd.read_csv('adult_with_headers.csv')
headers
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#check the data mean max
headers.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# check avilable columndata.info()
headers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#check missing data use isnull function
headers.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
#check duplicate data use duplicated function
headers=headers[headers.duplicated()]
headers
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
data=data.drop_duplicates()
data
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22367   44            Private  367749      Bachelors             13
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler,LabelEncoder

# Select only numerical features for scaling
numerical_features = headers.select_dtypes(include=['float64', 'int64']).columns

# Standard Scaling
standard_scaler = StandardScaler()
data_standard_scaled = headers.copy()
data_standard_scaled[numerical_features] = standard_scaler.fit_transform(headers[numerical_features])

# Display the first few rows of the Standard Scaled dataframe
print("\nStandard Scaled DataFrame:")
print(data_standard_scaled.head())
# Out:
# Standard Scaled DataFrame:
#             age workclass    fnlwgt      education  education_num  \
# 4881  -0.525861   Private  1.264249      Bachelors       1.296137
# 5104   3.596466   Private -1.391961   Some-college       0.423970
# 9171  -0.779543   Private  0.660916   Some-college       0.423970
# 11631 -0.842963   Private -0.817926   Some-college       0.423970
# 13084 -0.525861   Private  0.099500        1st-4th      -1.901808
#
#        marital_status        occupation    relationship                 race  \
# 4881    Never-married      Craft-repair   Not-in-family                White
# 5104    Never-married     Other-service   Not-in-family   Asian-Pac-Islander
# 9171    Never-married    Prof-specialty       Own-child                White
# 11631   Never-married      Tech-support   Not-in-family                White
# 13084   Never-married   Priv-house-serv   Not-in-family                White
#
# ...

# %%
# Min-Max Scaling
min_max_scaler = MinMaxScaler()
data_min_max_scaled = data.copy()
data_min_max_scaled[numerical_features] = min_max_scaler.fit_transform(data[numerical_features])

# Display the first few rows of the Min-Max Scaled dataframe
print("\nMin-Max Scaled DataFrame:")
print(data_min_max_scaled.head())
# Out:
# Min-Max Scaled DataFrame:
#             age workclass    fnlwgt      education  education_num  \
# 4881   0.084507   Private  0.794252      Bachelors       0.923077
# 5104   1.000000   Private  0.061511   Some-college       0.692308
# 9171   0.028169   Private  0.627817   Some-college       0.692308
# 11631  0.014085   Private  0.219864   Some-college       0.692308
# 13084  0.084507   Private  0.472945        1st-4th       0.076923
#
#        marital_status        occupation    relationship                 race  \
# 4881    Never-married      Craft-repair   Not-in-family                White
# 5104    Never-married     Other-service   Not-in-family   Asian-Pac-Islander
# 9171    Never-married    Prof-specialty       Own-child                White
# 11631   Never-married      Tech-support   Not-in-family                White
# 13084   Never-married   Priv-house-serv   Not-in-family                White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# ...

# %%
import pandas as pd
categorical_columns = data.select_dtypes(include=['object']).columns
# Apply One-Hot Encoding to categorical variables with less than 5 unique categories
for col in categorical_columns:
    if data[col].nunique() < 5:
        data= pd.get_dummies(data, columns=[col], prefix=[col], drop_first=True)
# Display the first few rows of the dataframe after One-Hot Encoding
print("\nDataFrame after One-Hot Encoding:")
print(data.head())
# Out:
# DataFrame after One-Hot Encoding:
#        age  fnlwgt      education  education_num        occupation  \
# 4881    25  308144      Bachelors             13      Craft-repair
# 5104    90   52386   Some-college             10     Other-service
# 9171    21  250051   Some-college             10    Prof-specialty
# 11631   20  107658   Some-college             10      Tech-support
# 13084   25  195994        1st-4th              2   Priv-house-serv
#
#        capital_gain  capital_loss  hours_per_week  \
# 4881              0             0              40
# 5104              0             0              35
# 9171              0             0              10
# 11631             0             0              10
# 13084             0             0              40
#
#        workclass_ Self-emp-not-inc  marital_status_ Married-civ-spouse  ...  \
# 4881                         False                               False  ...
# ...

# %%
categories_to_encode = headers.select_dtypes(include=['object']).columns  # Select categorical columns
for col in categories_to_encode:
    if headers[col].nunique() >5:# Check number of unique categories
        label_encoder = LabelEncoder()
        headers[col] = label_encoder.fit_transform(headers[col])

# Display the DataFrame after Label Encoding
print("\nDataFrame after Label Encoding:")
print(headers)
# Out:
# DataFrame after Label Encoding:
#        age          workclass  fnlwgt  education  education_num  \
# 4881    25            Private  308144          3             13
# 5104    90            Private   52386          7             10
# 9171    21            Private  250051          7             10
# 11631   20            Private  107658          7             10
# 13084   25            Private  195994          0              2
# 15059   21            Private  243368          6              1
# 17040   46            Private  173243          4              9
# 18555   30            Private  144593          4              9
# 18698   19            Private   97261          4              9
# 21318   19            Private  138153          7             10
# 21490   19            Private  146679          7             10
# 21875   49            Private   31267          2              4
# 22300   25            Private  195994          0              2
# ...

# %%
import matplotlib.pyplot as plt
# Plot histogram to visualize the distribution
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.hist(headers['fnlwgt'], bins=10, edgecolor='black')
plt.title('Histogram of Skewed Feature')
plt.xlabel('Values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Apply log transformation
import numpy as np
headers['log_feature1'] = np.log(headers['fnlwgt'])
headers['log_feature1']
# Out:
# C:\Users\binit\AppData\Local\Temp\ipykernel_8204\2452529548.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headers['log_feature1'] = np.log(headers['fnlwgt'])
# 4881     12.638322
# 5104     10.866395
# 9171     12.429420
# 11631    11.586715
# 13084    12.185839
# 15059    12.402330
# 17040    12.062451
# 18555    11.881678
# 18698    11.485153
# 21318    11.836117
# 21490    11.896002
# 21875    10.350319
# 22300    12.185839
# 22367    12.815156
# 22494    10.680033
# 25872    12.388965
# 26313    12.523358
# 28230    12.451299
# 28522    12.227027
# 28846    10.339029
# 29157    12.241449
# 30845    11.802725
# 31993    12.435512
# 32404    12.847819
# Name: log_feature1, dtype: float64

# %%
# Plot histogram of log-transformed feature
plt.subplot(1, 2, 2)
plt.hist(headers['log_feature1'], bins=10, edgecolor='black')
plt.title('Histogram of Log-Transformed Feature')
plt.xlabel('Log Values')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Feature Selection:

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
headers_encoded = pd.get_dummies(headers)
clf = IsolationForest(contamination=0.05, random_state=42)
outlier_preds = clf.fit_predict(headers_encoded)
headers_encoded = headers_encoded.fillna(0)
headers_encoded = headers_encoded.apply(pd.to_numeric, errors='coerce')
clf = IsolationForest(contamination=0.05, random_state=42)
outlier_preds = clf.fit_predict(headers_encoded)

# %%
headers['income_bracket'] = headers['income'].apply(lambda x: 1 if x == '>50K' else 0)
# Out:
# C:\Users\binit\AppData\Local\Temp\ipykernel_8204\1922237272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headers['income_bracket'] = headers['income'].apply(lambda x: 1 if x == '>50K' else 0)

# %%
headers['age_group'] = pd.cut(headers['age'], bins=[0, 25, 45, 65, 100], labels=['Young', 'Middle-Aged', 'Senior', 'Elder'])
# Out:
# C:\Users\binit\AppData\Local\Temp\ipykernel_8204\458416813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headers['age_group'] = pd.cut(headers['age'], bins=[0, 25, 45, 65, 100], labels=['Young', 'Middle-Aged', 'Senior', 'Elder'])

# %%
import numpy as np

headers['log_hours-per-week'] = np.log1p(headers['hours_per_week'])
# Out:
# C:\Users\binit\AppData\Local\Temp\ipykernel_8204\3395804861.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headers['log_hours-per-week'] = np.log1p(headers['hours_per_week'])

# %%
headers.head(1)
# Out:
#       age workclass  fnlwgt  education  education_num  marital_status  \
# 4881   25   Private  308144          3             13   Never-married
#
#       occupation    relationship    race    sex  capital_gain  capital_loss  \
# 4881           1   Not-in-family   White   Male             0             0
#
#       hours_per_week native_country  income  log_feature1  income_bracket  \
# 4881              40         Mexico   <=50K     12.638322               0
#
#      age_group
# 4881     Young

# %%
from sklearn.ensemble import IsolationForest

iso_forest = IsolationForest(contamination=0.05)
outliers = iso_forest.fit_predict(headers[['age', 'hours_per_week']])

# Mark outliers
headers['outlier'] = outliers
headers = headers[headers['outlier'] == 1]  # Keep only inliers
# Out:
# C:\Users\binit\AppData\Local\Temp\ipykernel_8204\710178100.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headers['outlier'] = outliers

# %%
# !pip install ppscore
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import ppscore as pps
pps_matrix = pps.matrix(headers)
pps_matrix
# Out:
# C:\Users\binit\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\binit\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\binit\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\binit\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# ...

# %%
# Calculate the correlation matrix (Pearson correlation)
import seaborn as sns
correlation_matrix = headers.corr(numeric_only=True)

# Display the correlation matrix
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                      age    fnlwgt  education  education_num  occupation  \
# age             1.000000 -0.351399   0.127638       0.158417   -0.083345
# fnlwgt         -0.351399  1.000000  -0.205552       0.146857    0.426840
# education       0.127638 -0.205552   1.000000       0.527723   -0.070870
# education_num   0.158417  0.146857   0.527723       1.000000    0.056460
# occupation     -0.083345  0.426840  -0.070870       0.056460    1.000000
# capital_gain         NaN       NaN        NaN            NaN         NaN
# capital_loss         NaN       NaN        NaN            NaN         NaN
# hours_per_week  0.251930  0.159910  -0.531948      -0.261491   -0.114048
# log_feature1   -0.469947  0.938495  -0.137094       0.096008    0.442020
#
#                 capital_gain  capital_loss  hours_per_week  log_feature1
# age                      NaN           NaN        0.251930     -0.469947
# ...

# %%
# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
